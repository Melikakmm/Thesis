# %%
import pandas as pd
import io

# %%
file_path = '/Users/melikakeshavarz/Desktop/Thesis/Model/Deep/o4rrl_bulge_ik_gpr_param.dat'

data = []
with open(file_path, 'r') as file:
    for line in file:
        out_line=line
        if line.startswith('# '):
            out_line=line.replace('# ', '')
        data.append(out_line)

df = pd.read_csv(io.StringIO(''.join(data)),delimiter = ' ')
df
# Out:
#            id  Nep_i    period  totamp_i   A1_i   A2_i   A3_i  A1_e_i  A2_e_i  \
# 0      b66145    108  0.842924     0.169  0.078  0.019  0.005   0.001   0.001
# 1      b65460    104  0.651459     0.187  0.076  0.032  0.006   0.008   0.008
# 2      b65415     50  0.489660     0.430  0.178  0.074  0.018   0.013   0.014
# 3      b65293    104  0.920575     0.155  0.070  0.015  0.007   0.003   0.003
# 4      b65247     55  0.564430     0.432  0.165  0.075  0.039   0.021   0.017
# ...       ...    ...       ...       ...    ...    ...    ...     ...     ...
# 28595  b29475     71  0.445642     0.900  0.324  0.132  0.129   0.028   0.028
# 28596  b44470    111  0.761321     0.793  0.238  0.147  0.109   0.016   0.016
# 28597  b25104     69  0.570071     0.441  0.150  0.090  0.042   0.022   0.022
# 28598  b45796    111  0.648343     0.625  0.183  0.119  0.079   0.014   0.013
# 28599  b21331     81  0.506560     0.389  0.158  0.067  0.035   0.025   0.021
#
# ...

# %%
df.columns
# Out:
# Index(['id', 'Nep_i', 'period', 'totamp_i', 'A1_i', 'A2_i', 'A3_i', 'A1_e_i',
#        'A2_e_i', 'A3_e_i', 'phi1_i', 'phi2_i', 'phi3_i', 'phi1_e_i',
#        'phi2_e_i', 'phi3_e_i', 'phi21_i', 'phi21_e_i', 'phi31_i', 'phi31_e_i',
#        'meanmag_i', 'meanmag_e_i', 'cost_i', 'costN_i', 'phcov_i', 'phcov2_i',
#        'snr_i', 'order_i', 'minmax_i', 'FeH', 'FeH_e', 'id_2', 'Nep_k',
#        'totamp_k', 'A1_k', 'A2_k', 'A3_k', 'phi1_k', 'phi2_k', 'phi3_k',
#        'phi21_k', 'phi31_k', 'meanmag_k', 'cost_k', 'costN_k', 'aper_k',
#        'phcov_k', 'phcov2_k', 'snr_k', 'ZPErr_k', 'Npt_k', 'order_k', 'minmax',
#        'RA', 'DEC', 'L', 'B', 'blazhko_prob', 'unmodulated_prob'],
#       dtype='object')

# %%
id period snr totamp phcov Nep meanmag
